# %% [markdown]
# # Outlook #

# %% [markdown]
# In this colab we will study basic reinforcement learning algorithms: TD learning, q-learning and sarsa. We will also investigate two basic exploration strategies: $\epsilon$-greedy and softmax.

# %% [markdown]
# # Installation #

# %%
# !pip ins tall importlib-metadata==4.13.0
# Out:
# ERROR: unknown command "ins" - maybe you meant "install"

# %%
# !pip install git+https://github.com/osigaud/bbrl_gym
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/osigaud/bbrl_gym
#   Cloning https://github.com/osigaud/bbrl_gym to /tmp/pip-req-build-42ck_v0_
#   Running command git clone --filter=blob:none --quiet https://github.com/osigaud/bbrl_gym /tmp/pip-req-build-42ck_v0_
#   Resolved https://github.com/osigaud/bbrl_gym to commit 5557075ecd7d4171ac0c21be3c69a94bcae655a9
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting gym==0.21.0
#   Downloading gym-0.21.0.tar.gz (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 55.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.19.1 in /usr/local/lib/python3.8/dist-packages (from bbrl-gym==1.2.5) (1.22.4)
# Collecting box2d-py
#   Downloading box2d-py-2.3.8.tar.gz (374 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.5/374.5 KB 40.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting mazemdp>=0.7.3
#   Downloading mazemdp-0.7.3-py3-none-any.whl (15 kB)
# Collecting swig
#   Downloading swig-4.1.1-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 77.2 MB/s eta 0:00:00
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.8/dist-packages (from gym==0.21.0->bbrl-gym==1.2.5) (2.2.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.8/dist-packages (from mazemdp>=0.7.3->bbrl-gym==1.2.5) (3.5.3)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib->mazemdp>=0.7.3->bbrl-gym==1.2.5) (4.38.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib->mazemdp>=0.7.3->bbrl-gym==1.2.5) (23.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->mazemdp>=0.7.3->bbrl-gym==1.2.5) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.8/dist-packages (from matplotlib->mazemdp>=0.7.3->bbrl-gym==1.2.5) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->mazemdp>=0.7.3->bbrl-gym==1.2.5) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib->mazemdp>=0.7.3->bbrl-gym==1.2.5) (8.4.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib->mazemdp>=0.7.3->bbrl-gym==1.2.5) (0.11.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7->matplotlib->mazemdp>=0.7.3->bbrl-gym==1.2.5) (1.15.0)
# Building wheels for collected packages: bbrl-gym, gym, box2d-py
#   Building wheel for bbrl-gym (pyproject.toml) ... done
#   Created wheel for bbrl-gym: filename=bbrl_gym-1.2.5-py3-none-any.whl size=17599 sha256=5aceb21347b049b51876464558e34fed7fe602c12db41856d23dbd2fb1ba1b2e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-p5tyxkzk/wheels/02/a5/fb/5c3661a0a660b77ec8a0dc817069457f0cc83f42b37daa0cb1
#   Building wheel for gym (setup.py) ... done
#   Created wheel for gym: filename=gym-0.21.0-py3-none-any.whl size=1616821 sha256=1dc9af0584ba2219eb03d38192c409fb4da7c31db56f0295bf6ed4f0a12b17c6
#   Stored in directory: /root/.cache/pip/wheels/27/6d/b3/a3a6e10704795c9b9000f1ab2dc480dfe7bed42f5972806e73
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Building wheel for box2d-py (setup.py) ... error
#   ERROR: Failed building wheel for box2d-py
#   Running setup.py clean for box2d-py
# Successfully built bbrl-gym gym
# Failed to build box2d-py
# Installing collected packages: swig, box2d-py, gym, mazemdp, bbrl-gym
#   Running setup.py install for box2d-py ... done
#   DEPRECATION: box2d-py was installed using the legacy 'setup.py install' method, because a wheel could not be built for it. A possible replacement is to fix the wheel build issue reported above. Discussion can be found at https://github.com/pypa/pip/issues/8368
#   Attempting uninstall: gym
#     Found existing installation: gym 0.25.2
#     Uninstalling gym-0.25.2:
#       Successfully uninstalled gym-0.25.2
# Successfully installed bbrl-gym-1.2.5 box2d-py-2.3.8 gym-0.21.0 mazemdp-0.7.3 swig-4.1.1

# %%
import os
from typing import Tuple, List

import numpy as np
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm

from mazemdp.toolbox import egreedy, egreedy_loc, softmax, sample_categorical
from mazemdp.maze_plotter import show_videos
from mazemdp.mdp import Mdp
from bbrl_gym.envs.maze_mdp import MazeMDPEnv

# For visualization
os.environ["VIDEO_FPS"] = "5"
if not os.path.isdir("./videos"):
    os.mkdir("./videos")

from IPython.display import Video

# Settings
NB_EPISODES = 100
TIMEOUT = 25
# Out:
# Matplotlib backend: module://ipykernel.pylab.backend_inline

# %% [markdown]
# # Reinforcement Learning #

# %% [markdown]
# Reinforcement Learning is about finding the optimal policy in an MDP which is initially unknown to the agent. More precisely, the state and action spaces are known, but the agent does not know the transition and reward functions. Generally speaking, the agent has to explore the MDP to figure out which action in which state leads to which other state and reward. The model-free case is about finding this optimal policy just through very local updates, without storing any information about previous interactions with the environment. Principles of these local updates can already be found in the Temporal Difference (TD) algorithm, which iteratively computes optimal values for all state using local updates.
# The most widely used model-free RL algorithms are **q-learning**, **sarsa** and **actor-critic** algorithms. Below we focus on the first two.

# %% [markdown]
# As for dynamic programming, we first create a maze-like MDP. Reinforcement learning is slower than dynamic programming, so we will work with smaller mazes.

# %%
import gym
import bbrl_gym


env = gym.make("MazeMDP-v0", kwargs={"width": 4, "height": 3, "ratio": 0.2})
env.reset()

# in dynamic programming, there is no agent moving in the environment
env.init_draw("The maze")
# Out:
# Output()

# %% [markdown]
# ## Temporal Difference (TD) learning ##

# %% [markdown]
# Given a state and an action spaces as well as a policy, TD(0) computes the state value of this policy based on the following equations:
# $$\delta_t = r(s_t,a_t) + \gamma V^{(t)}(s_{t+1})-V^{(t)}(s_t)$$
# $$V^{(t+1)}(s_t) = V^{(t)}(s_t) + \alpha\delta_t$$
#
# where $\delta$ is the TD error and $\alpha$ is a parameter called "learning rate".
#
# The code is provided below, so that you can take inspiration later on. The important part is the computation of $\delta$, and the update of the values of $V$.
#
# To run TD learning, a policy is needed as input. Such a policy can be retreived by using the `policy_iteration_q(mdp)` function defined in the dynamic programming notebook.
#
# If you want to run this notebook independently, you can use instead the `random_policy` provided in `mazemdp`. This is what we do here by default, replace it if you want to run TD learning from an optimal policy.

# %%
from mazemdp import random_policy

# %% [markdown]
# **Question:** In the code of the *temporal_difference(...)* function below, fill the missing parts with # some code = ...

# %%
def temporal_difference(
    mdp: MazeMDPEnv,
    policy: np.ndarray,
    nb_episodes: int = 50,
    alpha: float = 0.2,
    timeout: int = 25,
    render: bool = True,
) -> np.ndarray:
    # alpha: learning rate
    # timeout: timeout of an episode (maximum number of timesteps)
    v = np.zeros(mdp.nb_states)  # initial state value v
    mdp.timeout = timeout

    if render:
        mdp.init_draw("Temporal differences")

    for _ in tqdm(range(nb_episodes)):  # for each episode

        # Draw an initial state randomly (if uniform is set to False, the state is drawn according to the P0
        #                                 distribution)
        x = mdp.reset(uniform=True)
        done = False
        while not done:  # update episode at each timestep
            # Show agent
            if render:
                mdp.draw_v_pi(v, policy)

            # Step forward following the MDP: x=current state,
            #                                 pol[i]=agent's action according to policy pol,
            #                                 r=reward gained after taking action pol[i],
            #                                 done=tells whether the episode ended,
            #                                 and info gives some info about the process
            [y, r, done, _] = mdp.step(egreedy_loc(policy[x], mdp.action_space.n, epsilon=0.2))

            # To be completed...
            # assert False, 'Not implemented yet'
            delta = r+mdp.gamma*v[y]-v[x]
            v[x] = v[x]+alpha*delta

            # Update agent's position (state)
            x = y

    if render:
        # Show the final policy
        mdp.current_state = 0
        mdp.draw_v_pi(v, policy, title="Temporal Differences")
    return v

# %% [markdown]
# Once this is done, you can run it.

# %%
# Note that using a random policy, the chance to get an interesting value function is low
# Instead, you may get the value of an optimal policy obtained from a dynamic programming method
policy = random_policy(env)
v = temporal_difference(env, policy)
# Out:
# Output()
#   0%|          | 0/50 [00:00<?, ?it/s]

# %% [markdown]
# Unless you are lucky, the value function learned from a random policy will most probably be boring, as if it does not reach the rewarded state, all values keep at 0. To watch the behavior of the TD algorithm from an optimal policy, you can copy-paste from the dynamic programming lab the value iteration algorithm, use it to obtain an optimal policy and then call the TD algorithm from the obtained policy.

# %%
# ------------------ Value Iteration with the Q function ---------------------#
# Given a MDP, this algorithm computes the optimal action value function Q
# It then derives the optimal policy based on this function

def value_iteration_q(mdp: MazeMDPEnv, render: bool = True) -> Tuple[np.ndarray, List[float]]:
    q = np.zeros((mdp.nb_states, mdp.action_space.n))  # initial action values are set to 0
    q_list = []
    stop = False

    if render:
        mdp.init_draw("Value iteration Q")

    while not stop:
        qold = q.copy()

        if render:
            mdp.draw_v(q, title="Value iteration Q")

        for x in range(mdp.nb_states):# for each state x
        # Compute the value of the state x for each action u of the MDP action space
            if x not in mdp.terminal_states:
                for u in range(mdp.action_space.n):
                    summ = 0
                    for y in range(mdp.nb_states):
                        summ += mdp.P[x, u, y] * np.max(qold[y, :])
                    q[x,u]=mdp.r[x,u]+mdp.gamma*summ


                    # To be completed...
                    # assert False, 'Not implemented yet'

        if (np.linalg.norm(q - qold)) <= 0.01:
            stop = True
        q_list.append(np.linalg.norm(q))

    if render:
        mdp.draw_v(q, title="Value iteration Q")
        mdp.mdp.plotter.video_writer.release()

    return q, q_list

# %%
def get_policy_from_q(q: np.ndarray) -> np.ndarray:
    return np.argmax(q,axis=1)

# %%
q, _ = value_iteration_q(env)
policy = get_policy_from_q(q)
v = temporal_difference(env, policy)
# Out:
# Output()
#   0%|          | 0/50 [00:00<?, ?it/s]

# %% [markdown]
# ## Q-learning ##

# %% [markdown]
# The **q-learning** algorithm accounts for an agent exploring an MDP and updating at each step a model of the state action-value function stored into a Q-table. It is updated as follows:
#
# $$\delta_t = r(s_t,a_t) + \gamma \max_{a \in A} Q^{(t)}(s_{t+1},a)-Q^{(t)}(s_t,a_t)$$
#
# $$Q^{(t+1)}(s_t,a_t) = Q^{(t)}(s_t,a_t) + \alpha \delta_t.$$

# %% [markdown]
# To visualize the policy, we need the `get_policy_from_q(q)` function that we defined in the dynamic programming notebook. Import it below.

# %%
def get_policy_from_q(q: np.ndarray) -> np.ndarray:
    return np.argmax(q,axis=1)

# %% [markdown]
# **Question:**  Fill the code of the `q_learning(...)` function below.

# %%
# --------------------------- Q-Learning epsilon-greedy version -------------------------------#

# Given an exploration rate epsilon, the QLearning algorithm computes the state action-value function
# based on an epsilon-greedy policy
# alpha is the learning rate


def q_learning_eps(
    mdp: MazeMDPEnv,
    epsilon: float,
    nb_episodes: int = 30,
    timeout: int = 50,
    alpha: float = 0.5,
    render: bool = True,
) -> Tuple[np.ndarray, List[float]]:
    # Initialize the state-action value function
    # alpha is the learning rate
    q = np.zeros((mdp.nb_states, mdp.action_space.n))
    q_list = []

    # Run learning cycle
    mdp.timeout = timeout  # episode length

    if render:
        mdp.init_draw("Q-learning e-greedy")

    for _ in tqdm(range(nb_episodes)):
        # Draw the first state of episode i using a uniform distribution over all the states
        x = mdp.reset(uniform=True)
        done = False
        while not done:
            if render:
                # Show the agent in the maze
                mdp.draw_v_pi(q, q.argmax(axis=1))

            # Draw an action using an epsilon-greedy policy
            u = egreedy(q, x, epsilon)

            # Perform a step of the MDP
            [y, r, done, _] = mdp.step(u)

            # To be completed
            #assert False, 'Not implemented yet'
            delta = r+mdp.gamma*np.max(q[y,:])-q[x,u]
            q[x,u] = q[x,u]+alpha*delta

            # Update the agent position
            x = y
        q_list.append(np.linalg.norm(q))

    if render:
        # Show the final policy
        mdp.current_state = 0
        mdp.draw_v_pi(q, get_policy_from_q(q), title="Q-learning e-greedy")
    return q, q_list

# %% [markdown]
# And run it.

# %%
epsilon = 0.02
q, q_list = q_learning_eps(env, epsilon)
# Out:
# Output()
#   0%|          | 0/30 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-44faf1a3ea52> in <module>
#       1 epsilon = 0.02
# ----> 2 q, q_list = q_learning_eps(env, epsilon)
#
# <ipython-input-15-1c1a8f8ef311> in q_learning_eps(mdp, epsilon, nb_episodes, timeout, alpha, render)
#      32             if render:
#      33                 # Show the agent in the maze
# ---> 34                 mdp.draw_v_pi(q, q.argmax(axis=1))
#      35
#      36             # Draw an action using an epsilon-greedy policy
#
# /usr/local/lib/python3.8/dist-packages/bbrl_gym/envs/maze_mdp.py in draw_v_pi(self, v, policy, title, mode)
#      88     def draw_v_pi(self, v, policy, title="MDP studies", mode="legacy"):
#      89         agent_pos = None
# ---> 90         return self.mdp.render(v, policy, agent_pos, title, mode=mode)
#      91
#      92     def draw_v(self, v, mode="legacy", title="MDP studies"):
#
# /usr/local/lib/python3.8/dist-packages/mazemdp/mdp.py in render(self, v, policy, agent_pos, title, mode)
#     109             )
#     110         elif self.current_state is not None:
# --> 111             return self.plotter.render(
#     112                 v=v,
#     113                 agent_state=self.current_state,
#
# /usr/local/lib/python3.8/dist-packages/mazemdp/maze_plotter.py in render(self, v, policy, agent_state, stochastic, title, mode)
#     310         plot.fig.tight_layout()
#     311
# --> 312         plot.canvas.draw()
#     313         plot.canvas.flush_events()
#     314         rgba = np.asarray(plot.canvas.buffer_rgba())
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py in draw(self)
#     434              (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     435               else nullcontext()):
# --> 436             self.figure.draw(self.renderer)
#     437             # A GUI class may be need to update a window using this draw, so
#     438             # don't forget to call the superclass.
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      72     @wraps(draw)
#      73     def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 74         result = draw(artist, renderer, *args, **kwargs)
#      75         if renderer._rasterizing:
#      76             renderer.stop_rasterizing()
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      49                 renderer.start_filter()
#      50
# ---> 51             return draw(artist, renderer)
#      52         finally:
#      53             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/figure.py in draw(self, renderer)
#    2843
#    2844             self.patch.draw(renderer)
# -> 2845             mimage._draw_list_compositing_images(
#    2846                 renderer, self, artists, self.suppressComposite)
#    2847
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130     if not_composite or not has_images:
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#     134         # Composite any adjacent images together
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      49                 renderer.start_filter()
#      50
# ---> 51             return draw(artist, renderer)
#      52         finally:
#      53             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/axes/_base.py in draw(self, renderer)
#    3089             renderer.stop_rasterizing()
#    3090
# -> 3091         mimage._draw_list_compositing_images(
#    3092             renderer, self, artists, self.figure.suppressComposite)
#    3093
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130     if not_composite or not has_images:
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#     134         # Composite any adjacent images together
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      49                 renderer.start_filter()
#      50
# ---> 51             return draw(artist, renderer)
#      52         finally:
#      53             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/table.py in draw(self, renderer)
#     409
#     410         for key in sorted(self._cells):
# --> 411             self._cells[key].draw(renderer)
#     412
#     413         renderer.close_group('table')
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      49                 renderer.start_filter()
#      50
# ---> 51             return draw(artist, renderer)
#      52         finally:
#      53             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/table.py in draw(self, renderer)
#     144         super().draw(renderer)
#     145         # position the text
# --> 146         self._set_text_position(renderer)
#     147         self._text.draw(renderer)
#     148         self.stale = False
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/table.py in _set_text_position(self, renderer)
#     150     def _set_text_position(self, renderer):
#     151         """Set text up so it is drawn in the right place."""
# --> 152         bbox = self.get_window_extent(renderer)
#     153         # center vertically
#     154         y = bbox.y0 + bbox.height / 2
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/patches.py in get_window_extent(self, renderer)
#     627
#     628     def get_window_extent(self, renderer=None):
# --> 629         return self.get_path().get_extents(self.get_transform())
#     630
#     631     def _convert_xy_units(self, xy):
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/patches.py in get_transform(self)
#     276     def get_transform(self):
#     277         """Return the `~.transforms.Transform` applied to the `Patch`."""
# --> 278         return self.get_patch_transform() + artist.Artist.get_transform(self)
#     279
#     280     def get_data_transform(self):
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/patches.py in get_patch_transform(self)
#     756         # important to call the accessor method and not directly access the
#     757         # transformation member variable.
# --> 758         bbox = self.get_bbox()
#     759         return (transforms.BboxTransformTo(bbox)
#     760                 + transforms.Affine2D().rotate_deg_around(
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/patches.py in get_bbox(self)
#     849         """Return the `.Bbox`."""
#     850         x0, y0, x1, y1 = self._convert_units()
# --> 851         return transforms.Bbox.from_extents(x0, y0, x1, y1)
#     852
#     853     xy = property(get_xy, set_xy)
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/transforms.py in from_extents(minpos, *args)
#     837            scales where negative bounds result in floating point errors.
#     838         """
# --> 839         bbox = Bbox(np.reshape(args, (2, 2)))
#     840         if minpos is not None:
#     841             bbox._minpos[:] = minpos
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/overrides.py in reshape(*args, **kwargs)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Learning dynamics###

# %% [markdown]
# By watching carefully the values while the agent is learning, you can see that the agent favors certains paths over others which have a strictly equivalent value. This can be explained easily: as the agent chooses a path for the first time, it updates the values along that path, these values get higher than the surrounding values, and the agent chooses the same path again and again, increasing the phenomenon. Only steps of random exploration can counterbalance this effect, but they do so extremely slowly.

# %% [markdown]
# ### Exploration ###

# %% [markdown]
# In the `q_learning(...)` function above, action selection is based on an *$\epsilon$-greedy* policy. Instead, it could have relied on `softmax`.

# %% [markdown]
# **Question:** In the function below, you have to replace the call to the previous *$\epsilon$-greedy* policy with a `softmax` policy. The `softmax(...)` and `egreedy(...)` functions are available in `mazemdp.toolbox`.

# %% [markdown]
# To sample an action from a distribution of probabilities over discrete actions, you can use the ```sample_categorical(...)``` function.

# %%
# --------------------------- Q-Learning softmax version ----------------------------#

# Given a temperature "tau", the QLearning algorithm computes the state action-value function
# based on a softmax policy
# alpha is the learning rate


def q_learning_soft(
    mdp: MazeMDPEnv,
    tau: float,
    nb_episodes: int = 20,
    timeout: int = 50,
    alpha: float = 0.5,
    render: bool = True,
) -> Tuple[np.ndarray, List[float]]:
    # Initialize the state-action value function
    # alpha is the learning rate
    q = np.zeros((mdp.nb_states, mdp.action_space.n))
    q_list = []

    # Run learning cycle
    mdp.timeout = timeout  # episode length

    if render:
        mdp.init_draw("Q-learning softmax")

    for _ in tqdm(range(nb_episodes)):
        # Draw the first state of episode i using a uniform distribution over all the states
        x = mdp.reset(uniform=True)
        done = False
        while not done:
            if render:
                # Show the agent in the maze
                mdp.draw_v_pi(q, q.argmax(axis=1))

            # To be completed
            #assert False, 'Not implemented yet'
            tabU = softmax(q, x, tau)

            u = sample_categorical(tabU)

            [y, r, done, _] = mdp.step(u)

            # To be completed
            #assert False, 'Not implemented yet'
            delta = r+mdp.gamma*np.max(q[y,:])-q[x,u]
            q[x,u] = q[x,u]+alpha*delta


            x = y
        q_list.append(np.linalg.norm(q))

    if render:
        # Show the final policy
        mdp.current_state = 0
        mdp.draw_v_pi(q, get_policy_from_q(q), title="Q-learning softmax")
    return q, q_list

# %% [markdown]
# Run this new version

# %%
tau = 6
q, q_list = q_learning_soft(env, tau)
# Out:
# Output()
#   0%|          | 0/20 [00:00<?, ?it/s]

# %%
show_videos("videos/", "Q-learningsoftmax")
# Out:
# Converting videos/Q-learningsoftmax.avi
# <video alt="videos/Q-learningsoftmax.mp4" autoplay
#                     loop controls style="height: 400px;">
#                     <source src="data:video/mp4;base64,..." type="video/mp4" />
#                 </video>

# %% [markdown]
# ## Sarsa ##

# %% [markdown]
# The **sarsa** algorithm is very similar to **q-learning**. At first glance, the only difference is in the update rule. However, to perform the update in **sarsa**, one needs to know the action the agent will take when it will be at the next state, even if the agent is taking a random action.
#
# This implies that the next state action is determined in advance and stored for being played at the next time step.

# %% [markdown]
# **Question:** Fill the code below

# %%
# --------------------------- Sarsa, epsilon-greedy version -------------------------------#

# Given an exploration rate epsilon, the SARSA algorithm computes the state action-value function
# based on an epsilon-greedy policy
# alpha is the learning rate
def sarsa_eps(
    mdp: MazeMDPEnv,
    epsilon: float,
    nb_episodes: int = 20,
    timeout: int = 50,
    alpha: float = 0.5,
    render: bool = True,
) -> Tuple[np.ndarray, List[float]]:
    # Initialize the state-action value function
    # alpha is the learning rate
    q = np.zeros((mdp.nb_states, mdp.action_space.n))
    q_list = []

    # Run learning cycle
    mdp.timeout = timeout  # episode length

    if render:
        mdp.init_draw("Sarsa e-greedy")

    for _ in tqdm(range(nb_episodes)):
        # Draw the first state of episode i using a uniform distribution over all the states
        x = mdp.reset(uniform=True)
        done = False
        u_tempsT=egreedy_loc(policy[x], mdp.action_space.n, epsilon=0.2)

        while not done:
          # Show agent
          if render:
            # Show the agent in the maze
            mdp.draw_v_pi(q, q.argmax(axis=1))

          #u_tempsT=egreedy_loc(policy[x], mdp.action_space.n, epsilon=0.2)
          [y, r, done, _] = mdp.step(u_tempsT)

          u_tempsT1=egreedy_loc(policy[y], mdp.action_space.n, epsilon=0.2)

          q[x, u_tempsT]+= alpha*(r+mdp.gamma*q[y, u_tempsT1]-q[x, u_tempsT])

          x=y
          u_tempsT=u_tempsT1

        # To be completed
        #assert False, 'Not implemented yet'
        q_list.append(np.linalg.norm(q))

# for _ in tqdm(range(nb_episodes)):  # for each episode

#         # Draw an initial state randomly (if uniform is set to False, the state is drawn according to the P0
#         #                                 distribution)
#         x = mdp.reset(uniform=True)
#         done = False
#         while not done:  # update episode at each timestep
#             # Show agent
#             if render:
#                 mdp.draw_v_pi(v, policy)

#             # Step forward following the MDP: x=current state,
#             #                                 pol[i]=agent's action according to policy pol,
#             #                                 r=reward gained after taking action pol[i],
#             #                                 done=tells whether the episode ended,
#             #                                 and info gives some info about the process
#             [y, r, done, _] = mdp.step(egreedy_loc(policy[x], mdp.action_space.n, epsilon=0.2))

#             # To be completed...
#             # assert False, 'Not implemented yet'
#             delta = r+mdp.gamma*v[y]-v[x]
#             v[x] = v[x]+alpha*delta

#             # Update agent's position (state)
#             x = y


    if render:
        # Show the final policy
        mdp.current_state = 0
        mdp.draw_v_pi(q, get_policy_from_q(q), title="Sarsa e-greedy")
    return q, q_list

# %% [markdown]
# And run it.

# %%
epsilon = 0.02
q, q_list = sarsa_eps(env, epsilon)
# Out:
# Output()
#   0%|          | 0/20 [00:00<?, ?it/s]

# %%
show_videos("videos/", "Sarsae-greedy")

# %% [markdown]
# As for **q-learning** above, copy-paste the resulting code to get a *sarsa_soft(...)* and a *sarsa_eps(...)* function.

# %%
# --------------------------- Sarsa, softmax version -------------------------------#

# Given a temperature "tau", the SARSA algorithm computes the state action-value function
# based on a softmax policy
# alpha is the learning rate
def sarsa_soft(
    mdp: MazeMDPEnv,
    tau: float,
    nb_episodes: int = 20,
    timeout: int = 50,
    alpha: float = 0.5,
    render: bool = True,
) -> Tuple[np.ndarray, List[float]]:

    # Initialize the state-action value function
    # alpha is the learning rate
    q = np.zeros((mdp.nb_states, mdp.action_space.n))
    q_list = []

    # Run learning cycle
    mdp.timeout = timeout  # episode length

    if render:
        mdp.init_draw("Sarsa softmax")

    for _ in tqdm(range(nb_episodes)):
        # Draw the first state of episode i using a uniform distribution over all the states
        x = mdp.reset(uniform=True)
        done = False
        tabU=softmax(q, x, tau)

        u_tempsT=sample_categorical(tabU)

        while not done:
          # Show agent
          if render:
            # Show the agent in the maze
            mdp.draw_v_pi(q, q.argmax(axis=1))
          [y, r, done, _] = mdp.step(u_tempsT)

          tabU=softmax(q, y, tau)
          u_tempsT1=sample_categorical(tabU)

          q[x, u_tempsT]+= alpha*(r+mdp.gamma*q[y, u_tempsT1]-q[x, u_tempsT])

          x=y
          u_tempsT=u_tempsT1

        # To be completed
        #assert False, 'Not implemented yet'
        q_list.append(np.linalg.norm(q))

    if render:
        # Show the final policy
        mdp.current_state = 0
        mdp.draw_v_pi(q, get_policy_from_q(q), title="Sarsa softmax")
    return q, q_list

# %% [markdown]
# And run it.

# %%
tau = 6
q, q_list = sarsa_soft(env, tau, render = False)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]

# %%
show_videos("videos/", "Sarsasoftmax")
# Out:
# <video alt="videos/Sarsasoftmax.mp4" autoplay
#                     loop controls style="height: 400px;">
#                     <source src="data:video/mp4;base64,..." type="video/mp4" />
#                 </video>

# %% [markdown]
# ## Study part

# %% [markdown]
# ### Impact of `epsilon` and `beta` on q-learning and sarsa

# %% [markdown]
# Compare the number of steps needed by **q-learning** and **sarsa** to converge on a given MDP using the *softmax* and *$\epsilon$-greedy* exploration strategies. To figure out, you can use the provided `plot_ql_sarsa(m, epsilon, tau, nb_episodes, timeout, alpha, render)` function below with various values for $\epsilon$ (e.g. 0.001, 0.01, 0.1) and $\tau$ (e.g. 0.1, 5, 10) and comment the obtained curves. Other visualizations are welcome.

# %%
# -------- plot learning curves of Q-Learning and Sarsa using epsilon-greedy and softmax ----------#

def plot_ql_sarsa(env, epsilon, tau, nb_episodes, timeout, alpha, render):
    q, q_list1 = q_learning_eps(env, epsilon, nb_episodes, timeout, alpha, render)
    q, q_list2 = q_learning_soft(env, tau, nb_episodes, timeout, alpha, render)
    q, q_list3 = sarsa_eps(env, epsilon, nb_episodes, timeout, alpha, render)
    q, q_list4 = sarsa_soft(env, tau, nb_episodes, timeout, alpha, render)

    plt.clf()
    plt.plot(range(len(q_list1)), q_list1, label='q-learning epsilon')
    plt.plot(range(len(q_list2)), q_list2, label='q-learning tau')
    plt.plot(range(len(q_list3)), q_list3, label='sarsa epsilon')
    plt.plot(range(len(q_list4)), q_list4, label='sarsa tau')

    plt.xlabel('Number of episodes')
    plt.ylabel('Norm of Q values')
    plt.legend(loc='lower right')
    plt.savefig("comparison_RL.png")
    plt.title("Comparison of convergence rates")
    plt.show()

# %%
# example
epsilon = 0.1
tau = 10
print(env.gamma)
plot_ql_sarsa(env, epsilon, tau, 100, 200, 0.5, False)
# Out:
# 0.9
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]

# %% [markdown]
# ### Effect of hyper-parameters

# %% [markdown]
# The other two hyper-parameters of **q-learning** and **sarsa** are $\alpha$, and $\gamma$. By varying the values of these hyper-parameters and watching the learning process and behavior of the agent, explain their impact on the algorithm. Using additional plotting functions is also welcome.

# %%
def plot_alpha(env, epsilon, tau, nb_episodes, timeout, alpha_range, render):
  for alpha in alpha_range:
    q, q_list1 = q_learning_eps(env, epsilon, nb_episodes, timeout, alpha, render)
    q, q_list2 = q_learning_soft(env, tau, nb_episodes, timeout, alpha, render)
    q, q_list3 = sarsa_eps(env, epsilon, nb_episodes, timeout, alpha, render)
    q, q_list4 = sarsa_soft(env, tau, nb_episodes, timeout, alpha, render)

    print("alpha = ", alpha)
    plt.clf()
    plt.plot(range(len(q_list1)), q_list1, label='q-learning epsilon')
    plt.plot(range(len(q_list2)), q_list2, label='q-learning tau')
    plt.plot(range(len(q_list3)), q_list3, label='sarsa epsilon')
    plt.plot(range(len(q_list4)), q_list4, label='sarsa tau')

    plt.xlabel('Number of episodes')
    plt.ylabel('Norm of Q values')
    plt.legend(loc='lower right')
    plt.savefig("comparison_RL_alpha.png")
    plt.title("Comparison of convergence rates in function of alpha")
    plt.show()

# %%
alpha_range = [0.01, 0.1, 0.9, 1.2, 2]
plot_alpha(env, 0.01, 5, 1500, 100, alpha_range, False)
# Out:
#   0%|          | 0/1500 [00:00<?, ?it/s]
#   0%|          | 0/1500 [00:00<?, ?it/s]
#   0%|          | 0/1500 [00:00<?, ?it/s]
#   0%|          | 0/1500 [00:00<?, ?it/s]
# alpha =  0.01
#   0%|          | 0/1500 [00:00<?, ?it/s]
#   0%|          | 0/1500 [00:00<?, ?it/s]
#   0%|          | 0/1500 [00:00<?, ?it/s]
#   0%|          | 0/1500 [00:00<?, ?it/s]
# alpha =  0.1
#   0%|          | 0/1500 [00:00<?, ?it/s]
#   0%|          | 0/1500 [00:00<?, ?it/s]
#   0%|          | 0/1500 [00:00<?, ?it/s]
#   0%|          | 0/1500 [00:00<?, ?it/s]
# alpha =  0.9
#   0%|          | 0/1500 [00:00<?, ?it/s]
#   0%|          | 0/1500 [00:00<?, ?it/s]
#   0%|          | 0/1500 [00:00<?, ?it/s]
#   0%|          | 0/1500 [00:00<?, ?it/s]
# alpha =  1.2
#   0%|          | 0/1500 [00:00<?, ?it/s]
#   0%|          | 0/1500 [00:00<?, ?it/s]
#   0%|          | 0/1500 [00:00<?, ?it/s]
#   0%|          | 0/1500 [00:00<?, ?it/s]
# alpha =  2

# %%
def plot_gamma(env, epsilon, tau, nb_episodes, timeout, alpha, render, gamma_range):
  for gamma in gamma_range:
    env.gamma = gamma
    q, q_list1 = q_learning_eps(env, epsilon, nb_episodes, timeout, alpha, render)
    q, q_list2 = q_learning_soft(env, tau, nb_episodes, timeout, alpha, render)
    q, q_list3 = sarsa_eps(env, epsilon, nb_episodes, timeout, alpha, render)
    q, q_list4 = sarsa_soft(env, tau, nb_episodes, timeout, alpha, render)

    print("gamma = ", gamma)
    plt.clf()
    plt.plot(range(len(q_list1)), q_list1, label='q-learning epsilon')
    plt.plot(range(len(q_list2)), q_list2, label='q-learning tau')
    plt.plot(range(len(q_list3)), q_list3, label='sarsa epsilon')
    plt.plot(range(len(q_list4)), q_list4, label='sarsa tau')

    plt.xlabel('Number of episodes')
    plt.ylabel('Norm of Q values')
    plt.legend(loc='lower right')
    plt.savefig("comparison_RL_alpha.png")
    plt.title("Comparison of convergence rates in function of gamma")
    plt.show()

# %%
gamma_range = [0, 0.01, 0.1, 0.6, 1]
plot_gamma(env, 0.01, 5, 1400, 200, 0.5, False, gamma_range)
# Out:
#   0%|          | 0/1400 [00:00<?, ?it/s]
#   0%|          | 0/1400 [00:00<?, ?it/s]
#   0%|          | 0/1400 [00:00<?, ?it/s]
#   0%|          | 0/1400 [00:00<?, ?it/s]
# gamma =  0
#   0%|          | 0/1400 [00:00<?, ?it/s]
#   0%|          | 0/1400 [00:00<?, ?it/s]
#   0%|          | 0/1400 [00:00<?, ?it/s]
#   0%|          | 0/1400 [00:00<?, ?it/s]
# gamma =  0.01
#   0%|          | 0/1400 [00:00<?, ?it/s]
#   0%|          | 0/1400 [00:00<?, ?it/s]
#   0%|          | 0/1400 [00:00<?, ?it/s]
#   0%|          | 0/1400 [00:00<?, ?it/s]
# gamma =  0.1
#   0%|          | 0/1400 [00:00<?, ?it/s]
#   0%|          | 0/1400 [00:00<?, ?it/s]
#   0%|          | 0/1400 [00:00<?, ?it/s]
#   0%|          | 0/1400 [00:00<?, ?it/s]
# gamma =  0.6
#   0%|          | 0/1400 [00:00<?, ?it/s]
#   0%|          | 0/1400 [00:00<?, ?it/s]
#   0%|          | 0/1400 [00:00<?, ?it/s]
#   0%|          | 0/1400 [00:00<?, ?it/s]
# gamma =  1
